# %%
import requests

DEFAULT_MESSAGE_TEMPLATE = "<s>{role}\n{content}</s>"
DEFAULT_RESPONSE_TEMPLATE = "<s>bot\n"
DEFAULT_SYSTEM_PROMPT = "Ты — Сайга, русскоязычный автоматический ассистент. Ты разговариваешь с людьми и помогаешь им."

class Conversation:
    def __init__(
        self,
        message_template=DEFAULT_MESSAGE_TEMPLATE,
        system_prompt=DEFAULT_SYSTEM_PROMPT,
        response_template=DEFAULT_RESPONSE_TEMPLATE
    ):
        self.message_template = message_template
        self.response_template = response_template
        self.messages = [{
            "role": "system",
            "content": system_prompt
        }]

    def add_user_message(self, message):
        self.messages.append({
            "role": "user",
            "content": message
        })

    def add_bot_message(self, message):
        self.messages.append({
            "role": "bot",
            "content": message
        })

    def get_prompt(self):
        final_text = ""
        for message in self.messages:
            message_text = self.message_template.format(**message)
            final_text += message_text
        final_text += DEFAULT_RESPONSE_TEMPLATE
        return final_text.strip()

# %%
import pandas as pd

df = pd.read_csv('../RuSentNE-evaluation/val.csv')
df
# Out:
#                                              sentence  \
# 0   Однако в четверг представитель неправительстве...
# 1   Речь идет о скандальном деле Mediaset, в рамка...
# 2   А вот у Bruins неожиданно блещут Давид Крейчи ...
# 3   Президенту Бразилии Дилме Руссефф грозит импич...
# 4   ODS в лице своего нового председателя Мартина ...
# 5   Ключевым свидетелем против Насера стал его соб...
# 6   Чавес является ярым критиком Соединенных Штато...
# 7   Некоторые коллеги зовут канадскую писательницу...
# 8   С другой стороны, премьер-министр Белиза Дин Б...
# 9   В пресс-релизе говорится, что Леонард Пелтиер ...
# 10  Ведь не секрет, что 2010 год, при всех успехах...
# 11  При этом ''Netflix'' выразил глубокую озабочен...
# 12  Он уступает лишь легендарному Крису Челиосу, к...
# 13  В этой публикации утверждается, что президент ...
# 14  Полный список держался в секрете, однако экспе...
# 15  Знаменитый исполнитель подростковой поп-музыки...
# 16       Дизайнеру ИГИЛ предъявлены обвинения в Индии
# 17  В годы своего расцвета Кирк Дуглас мог снимать...
# 18  Некоторые коллеги зовут канадскую писательницу...
# 19  Мальчишки брали у именитого футболиста автогра...
# 20  Еще одним фаворитом кампании считается 63-летн...
# 21  На суде в Перми обвинитель представил отрицате...
# 22  Может, они перестанут делать из Госдумы болото...
# 23  Альбом ''Double Fantasy'' Джона Леннона и его ...
# 24  Кроме художественной прозы писал сатирические ...
# 25  Женщина с безупречной репутацией на посту прем...
# 26  До этого он успел поработать в известных IT-ко...
# 27  По словам Черноскулова, «от соперничества с Ан...
# 28  В те времена коммунистическое правительство Ку...
# 29  В ответ спикер Госдумы Сергей Нарышкин пообеща...
# 30  Ранее это сделал депутат от «Справедливой Росс...
# 31  Юноша клянется в преданности «халифу» аль-Багд...
# 32  Интересна дуэль вратарей: один из лучших канад...
# 33  Хотя у Мадуро нет харизмы Чавеса, он пользуетс...
# 34  «Согласно конституции, если инаугурация презид...
# 35  У Александра фантастическая защита, все надеял...
# 36  По сообщению портала Ivanovo News работы участ...
# 37  Речь идет о скандальном деле Mediaset, в рамка...
# 38  Насер стал вторым гражданином Индии, которому ...
# 39  Президент Бразилии Дилма Руссефф борется свою ...
# 40  В своём фейсбук-аккаунте Ивоби назвал главу «Л...
# 41  Напомним, что в 2011 году Бардо написала премь...
# 42  Netflix закрывает сериал «Карточный домик» на ...
# 43  Таким образом мошенникам удалось получить боле...
# 44  В случае описанной череды неудачных предложени...
# 45    Адвокаты лётчицы настаивают, что она невиновна.
# 46  Берлускони ушел в отставку немногим более года...
# 47  Скандально известная фигура в стране - Берлуск...
# 48  Столь же жесткой была партийная реакция на инт...
# 49  А вот у Bruins неожиданно блещут Давид Крейчи ...
#
#                         entity         pos  \
# 0                    Цвангираи  [206, 215]
# 1                     Mediaset    [29, 37]
# 2                 Давид Крейчи    [33, 45]
# 3                Дилме Руссефф    [20, 33]
# 4   технического правительства  [103, 129]
# 5                       Насера    [27, 33]
# 6                          США  [118, 121]
# 7                 писательницу    [34, 46]
# 8                 Джона Макафи    [59, 71]
# 9              Леонард Пелтиер    [30, 45]
# 10                      Google    [47, 53]
# 11               Кевина Спейси  [152, 165]
# 12               Крису Челиосу    [30, 43]
# 13                   политиков    [88, 97]
# 14               Грету Тунберг  [226, 239]
# 15               Джастин Бибер    [47, 60]
# 16              Дизайнеру ИГИЛ     [0, 14]
# 17                 Кирк Дуглас    [23, 34]
# 18                     Чеховым    [54, 61]
# 19                  футболиста    [28, 38]
# 20               Сумаила Сиссе    [49, 62]
# 21                     Алехина   [98, 105]
# 22                     Госдумы    [32, 39]
# 23               Марка Чепмена  [109, 122]
# 24                    юмористы  [154, 162]
# 25                     Нечасом   [93, 100]
# 26                         Sun    [65, 68]
# 27                     Андреем    [44, 51]
# 28                 The Beatles  [162, 173]
# 29                  Пономарева  [178, 188]
# 30               Единую Россию  [106, 119]
# 31                       Сирии  [144, 149]
# 32                   Тим Томас  [120, 129]
# 33                      Чавеса    [26, 32]
# 34                      Чавеса  [226, 232]
# 35                  Александра     [2, 12]
# 36                      ученые    [71, 77]
# 37                  Берлускони    [57, 67]
# 38                        ИГИЛ   [96, 100]
# 39               Дилма Руссефф    [19, 32]
# 40             Маттео Сальвини    [51, 66]
# 41                      Путину    [57, 63]
# 42              Кевином Спейси    [62, 76]
# 43                  Мардахаеву  [138, 148]
# 44                  президента    [48, 58]
# 45                     лётчицы     [9, 16]
# 46   правительство технократов  [128, 153]
# 47                  Берлускони    [39, 49]
# 48           федеральный центр  [125, 142]
# 49                Натан Хортон    [63, 75]
#
#                                         opinion_words  label
# 0                                     ['катастрофой']     -1
# 1                                     ['скандальном']     -1
# 2                                          ['блещут']      1
# 3                                       ['импичмент']     -1
# 4                                    ['не поддержит']     -1
# 5                               ['свидетелем против']     -1
# 6                                    ['недружелюбно']     -1
# 7                   ['интересных коротких рассказов']      1
# 8                                      ['параноиком']     -1
# 9         ['сомнений в справедливости его осуждения']      1
# 10                                        ['успехах']      1
# 11          ['глубокую озабоченность', 'обвинениями']     -1
# 12                                   ['легендарному']      1
# 13                              ['коппрумпированных']     -1
# 14                                      ['фаворитов']      1
# 15                                     ['Знаменитый']      1
# 16                                      ['обвинения']     -1
# 17                                       ['расцвета']      1
# 18  ['великим русским писателем', 'интересных коро...      1
# 19                                      ['именитого']      1
# 20                             ['фаворитом кампании']      1
# 21                                  ['отрицательную']     -1
# 22                                         ['болото']     -1
# 23                                        ['убийцей']     -1
# 24                                      ['известные']      1
# 25                                       ['скандала']     -1
# 26                                      ['известных']      1
# 27                                ['очень интересно']      1
# 28                            ['большим подозрением']     -1
# 29                          ['вруном', 'слово ранит']     -1
# 30                         ['партию жуликов и воров']     -1
# 31                                      ['неверными']     -1
# 32              ['один из лучших канадских вратарей']      1
# 33                                        ['харизмы']      1
# 34                                 ['поддерживающий']      1
# 35                                 ['фантастическая']      1
# 36                                       ['именитые']      1
# 37                                    ['скандальном']     -1
# 38                                      ['обвинения']     -1
# 39                                     ['импичменте']     -1
# 40                                ['великим лидером']      1
# 41                      ['президентом своего сердца']      1
# 42                                       ['скандала']     -1
# 43                                     ['мошенникам']     -1
# 44                                      ['неудачных']     -1
# 45                                      ['невиновна']     -1
# 46                                   ['непопулярную']     -1
# 47                                      ['обвинялся']     -1
# 48                    ['невнимание', 'раскритиковал']     -1
# 49                                         ['блещут']      1

# %%
INSTRUCTION = 'Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями \"тональность\" и \"оценочное слово\".'
PROMPT = '''Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями \"тональность\" и \"оценочное слово\".
Предложение: {sent}
Сущность: {entity}'''

# %%
print(prompt_raw)
# Out:
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: А вот у Bruins неожиданно блещут Давид Крейчи (десять голов) и Натан Хортон (восемь шайб).
# Сущность: Давид Крейчи

# %%
few_shot_examples = df.sample(1)
few_shot_examples
# Out:
#                                              sentence          entity  \
# 42  Netflix закрывает сериал «Карточный домик» на ...  Кевином Спейси
#
#          pos opinion_words  label
# 42  [62, 76]  ['скандала']     -1

# %%
answers = []
answer_prompt = '{\n  \"тональность\": \"{sentiment}\",\n  \"оценочное слово\": \"{words}\"\n}'
for i, row in few_shot_examples.iterrows():
    sentiment = 'положительная' if row['label'] == 1 else 'негативная'
    words = ';'.join(eval(row['opinion_words']))
    answers.append(answer_prompt.replace('{sentiment}', sentiment).replace('{words}', words))
answers
# Out:
# ['{\n  "тональность": "негативная",\n  "оценочное слово": "скандала"\n}']

# %%
few_shot_examples['answers'] = answers

# %%
few_shot_examples['answer'] = few_shot_examples.apply(lambda row: '{\n  "тональность": "положительная",\n  "оценочное слово": "блещут"\n}',axis=1)

# %%
conversation = Conversation()
for i, row in few_shot_examples.iterrows():
    sent = row['sentence']
    entity = row['entity']
    prompt_raw = PROMPT.replace('{sent}', sent).replace('{entity}', entity)
    conversation.add_user_message(prompt_raw)
    conversation.add_bot_message(row['answers'])
print(conversation.get_prompt())
# Out:
# <s>system
# Ты — Сайга, русскоязычный автоматический ассистент. Ты разговариваешь с людьми и помогаешь им.</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: Netflix закрывает сериал «Карточный домик» на фоне скандала с Кевином Спейси
# Сущность: Кевином Спейси</s><s>bot
# {
#   "тональность": "негативная",
#   "оценочное слово": "скандала"
# }</s><s>bot

# %%
few_shot_prompt = PROMPT

# %%
import copy 
from tqdm import tqdm
import requests
import json
host = 'http://localhost:5005/generate'

predict = []
for i, row in tqdm(df.iterrows()):
    #if i < 11:
    #    continue
    sent = row['sentence']
    entity = row['entity']
    prompt_raw = PROMPT.replace('{sent}', sent).replace('{entity}', entity)
    #conv = copy.deepcopy(conversation)
    conv = Conversation()
    conv.add_user_message(prompt_raw)
    prompt = conv.get_prompt()
    r = requests.post(host, json.dumps({'model_name': 'mistral_ru', 'prompt': prompt, 'temperature': 0.01}))
    predict.append(json.loads(r.text)['text'])
    #break
#print(row)
#print(json.loads(r.text)['text'])
# Out:
# 50it [00:57,  1.15s/it]

# %%
from nltk import edit_distance

def find_lcs(s1, s2):
    max_lcs = ""
    for i in range(len(s1)):
        for j in range(i + 1, len(s1) + 1):
            ss1 = s1[i:j]
            if ss1 in s2 and len(ss1) > len(max_lcs):
                max_lcs = ss1
    return max_lcs

def clean_rucos_response(response, entities):
    answers = []
    for answer in entities:
        lcs = find_lcs(response.strip(), answer.strip())
        answers.append((len(lcs), answer))
    return max(answers)

# %%
import numpy as np
def eval_words(response, answers):
    res = []
    for answer in answers:
        lcs = find_lcs(response.strip().lower(), answer.strip().lower())
        edit = edit_distance(response.lower().strip(), answer.lower().strip())
        lcs_metric = len(lcs) / max(len(response.strip()), len(answer.strip()))
        edit_metric = 1 / np.log2(2 + edit)
        res.append([np.mean([lcs_metric, edit_metric]), lcs_metric, edit_metric, answer])
    res = sorted(res, key=lambda x: -x[0])
    return res[0]

# %%
df
# Out:
#                                              sentence  \
# 0   Однако в четверг представитель неправительстве...
# 1   Речь идет о скандальном деле Mediaset, в рамка...
# 2   А вот у Bruins неожиданно блещут Давид Крейчи ...
# 3   Президенту Бразилии Дилме Руссефф грозит импич...
# 4   ODS в лице своего нового председателя Мартина ...
# 5   Ключевым свидетелем против Насера стал его соб...
# 6   Чавес является ярым критиком Соединенных Штато...
# 7   Некоторые коллеги зовут канадскую писательницу...
# 8   С другой стороны, премьер-министр Белиза Дин Б...
# 9   В пресс-релизе говорится, что Леонард Пелтиер ...
# 10  Ведь не секрет, что 2010 год, при всех успехах...
# 11  При этом ''Netflix'' выразил глубокую озабочен...
# 12  Он уступает лишь легендарному Крису Челиосу, к...
# 13  В этой публикации утверждается, что президент ...
# 14  Полный список держался в секрете, однако экспе...
# 15  Знаменитый исполнитель подростковой поп-музыки...
# 16       Дизайнеру ИГИЛ предъявлены обвинения в Индии
# 17  В годы своего расцвета Кирк Дуглас мог снимать...
# 18  Некоторые коллеги зовут канадскую писательницу...
# 19  Мальчишки брали у именитого футболиста автогра...
# 20  Еще одним фаворитом кампании считается 63-летн...
# 21  На суде в Перми обвинитель представил отрицате...
# 22  Может, они перестанут делать из Госдумы болото...
# 23  Альбом ''Double Fantasy'' Джона Леннона и его ...
# 24  Кроме художественной прозы писал сатирические ...
# 25  Женщина с безупречной репутацией на посту прем...
# 26  До этого он успел поработать в известных IT-ко...
# 27  По словам Черноскулова, «от соперничества с Ан...
# 28  В те времена коммунистическое правительство Ку...
# 29  В ответ спикер Госдумы Сергей Нарышкин пообеща...
# 30  Ранее это сделал депутат от «Справедливой Росс...
# 31  Юноша клянется в преданности «халифу» аль-Багд...
# 32  Интересна дуэль вратарей: один из лучших канад...
# 33  Хотя у Мадуро нет харизмы Чавеса, он пользуетс...
# 34  «Согласно конституции, если инаугурация презид...
# 35  У Александра фантастическая защита, все надеял...
# 36  По сообщению портала Ivanovo News работы участ...
# 37  Речь идет о скандальном деле Mediaset, в рамка...
# 38  Насер стал вторым гражданином Индии, которому ...
# 39  Президент Бразилии Дилма Руссефф борется свою ...
# 40  В своём фейсбук-аккаунте Ивоби назвал главу «Л...
# 41  Напомним, что в 2011 году Бардо написала премь...
# 42  Netflix закрывает сериал «Карточный домик» на ...
# 43  Таким образом мошенникам удалось получить боле...
# 44  В случае описанной череды неудачных предложени...
# 45    Адвокаты лётчицы настаивают, что она невиновна.
# 46  Берлускони ушел в отставку немногим более года...
# 47  Скандально известная фигура в стране - Берлуск...
# 48  Столь же жесткой была партийная реакция на инт...
# 49  А вот у Bruins неожиданно блещут Давид Крейчи ...
#
#                         entity         pos  \
# 0                    Цвангираи  [206, 215]
# 1                     Mediaset    [29, 37]
# 2                 Давид Крейчи    [33, 45]
# 3                Дилме Руссефф    [20, 33]
# 4   технического правительства  [103, 129]
# 5                       Насера    [27, 33]
# 6                          США  [118, 121]
# 7                 писательницу    [34, 46]
# 8                 Джона Макафи    [59, 71]
# 9              Леонард Пелтиер    [30, 45]
# 10                      Google    [47, 53]
# 11               Кевина Спейси  [152, 165]
# 12               Крису Челиосу    [30, 43]
# 13                   политиков    [88, 97]
# 14               Грету Тунберг  [226, 239]
# 15               Джастин Бибер    [47, 60]
# 16              Дизайнеру ИГИЛ     [0, 14]
# 17                 Кирк Дуглас    [23, 34]
# 18                     Чеховым    [54, 61]
# 19                  футболиста    [28, 38]
# 20               Сумаила Сиссе    [49, 62]
# 21                     Алехина   [98, 105]
# 22                     Госдумы    [32, 39]
# 23               Марка Чепмена  [109, 122]
# 24                    юмористы  [154, 162]
# 25                     Нечасом   [93, 100]
# 26                         Sun    [65, 68]
# 27                     Андреем    [44, 51]
# 28                 The Beatles  [162, 173]
# 29                  Пономарева  [178, 188]
# 30               Единую Россию  [106, 119]
# 31                       Сирии  [144, 149]
# 32                   Тим Томас  [120, 129]
# 33                      Чавеса    [26, 32]
# 34                      Чавеса  [226, 232]
# 35                  Александра     [2, 12]
# 36                      ученые    [71, 77]
# 37                  Берлускони    [57, 67]
# 38                        ИГИЛ   [96, 100]
# 39               Дилма Руссефф    [19, 32]
# 40             Маттео Сальвини    [51, 66]
# 41                      Путину    [57, 63]
# 42              Кевином Спейси    [62, 76]
# 43                  Мардахаеву  [138, 148]
# 44                  президента    [48, 58]
# 45                     лётчицы     [9, 16]
# 46   правительство технократов  [128, 153]
# 47                  Берлускони    [39, 49]
# 48           федеральный центр  [125, 142]
# 49                Натан Хортон    [63, 75]
#
#                                         opinion_words  label
# 0                                     ['катастрофой']     -1
# 1                                     ['скандальном']     -1
# 2                                          ['блещут']      1
# 3                                       ['импичмент']     -1
# 4                                    ['не поддержит']     -1
# 5                               ['свидетелем против']     -1
# 6                                    ['недружелюбно']     -1
# 7                   ['интересных коротких рассказов']      1
# 8                                      ['параноиком']     -1
# 9         ['сомнений в справедливости его осуждения']      1
# 10                                        ['успехах']      1
# 11          ['глубокую озабоченность', 'обвинениями']     -1
# 12                                   ['легендарному']      1
# 13                              ['коппрумпированных']     -1
# 14                                      ['фаворитов']      1
# 15                                     ['Знаменитый']      1
# 16                                      ['обвинения']     -1
# 17                                       ['расцвета']      1
# 18  ['великим русским писателем', 'интересных коро...      1
# 19                                      ['именитого']      1
# 20                             ['фаворитом кампании']      1
# 21                                  ['отрицательную']     -1
# 22                                         ['болото']     -1
# 23                                        ['убийцей']     -1
# 24                                      ['известные']      1
# 25                                       ['скандала']     -1
# 26                                      ['известных']      1
# 27                                ['очень интересно']      1
# 28                            ['большим подозрением']     -1
# 29                          ['вруном', 'слово ранит']     -1
# 30                         ['партию жуликов и воров']     -1
# 31                                      ['неверными']     -1
# 32              ['один из лучших канадских вратарей']      1
# 33                                        ['харизмы']      1
# 34                                 ['поддерживающий']      1
# 35                                 ['фантастическая']      1
# 36                                       ['именитые']      1
# 37                                    ['скандальном']     -1
# 38                                      ['обвинения']     -1
# 39                                     ['импичменте']     -1
# 40                                ['великим лидером']      1
# 41                      ['президентом своего сердца']      1
# 42                                       ['скандала']     -1
# 43                                     ['мошенникам']     -1
# 44                                      ['неудачных']     -1
# 45                                      ['невиновна']     -1
# 46                                   ['непопулярную']     -1
# 47                                      ['обвинялся']     -1
# 48                    ['невнимание', 'раскритиковал']     -1
# 49                                         ['блещут']      1

# %%
def create_submit(predict):
    sentiment_list = []
    words_list = []
    for i, pred in enumerate(predict):
        sentiment = -1
        words = ''
        try:
            pred = eval(pred)
            sentiment = pred['тональность'].strip().lower()
            words = pred['оценочное слово'].strip().lower()
            sentiment = -1 if sentiment == 'негативная' else 1
        except:
            pass
        sentiment_list.append(sentiment)
        words_list.append(words)

    df_pred = pd.DataFrame()
    df_pred['sentiment'] = sentiment_list
    df_pred['opinion_words'] = words_list
    return df_pred

# %%
df
# Out:
#                                              sentence  \
# 0   Однако в четверг представитель неправительстве...
# 1   Речь идет о скандальном деле Mediaset, в рамка...
# 2   А вот у Bruins неожиданно блещут Давид Крейчи ...
# 3   Президенту Бразилии Дилме Руссефф грозит импич...
# 4   ODS в лице своего нового председателя Мартина ...
# 5   Ключевым свидетелем против Насера стал его соб...
# 6   Чавес является ярым критиком Соединенных Штато...
# 7   Некоторые коллеги зовут канадскую писательницу...
# 8   С другой стороны, премьер-министр Белиза Дин Б...
# 9   В пресс-релизе говорится, что Леонард Пелтиер ...
# 10  Ведь не секрет, что 2010 год, при всех успехах...
# 11  При этом ''Netflix'' выразил глубокую озабочен...
# 12  Он уступает лишь легендарному Крису Челиосу, к...
# 13  В этой публикации утверждается, что президент ...
# 14  Полный список держался в секрете, однако экспе...
# 15  Знаменитый исполнитель подростковой поп-музыки...
# 16       Дизайнеру ИГИЛ предъявлены обвинения в Индии
# 17  В годы своего расцвета Кирк Дуглас мог снимать...
# 18  Некоторые коллеги зовут канадскую писательницу...
# 19  Мальчишки брали у именитого футболиста автогра...
# 20  Еще одним фаворитом кампании считается 63-летн...
# 21  На суде в Перми обвинитель представил отрицате...
# 22  Может, они перестанут делать из Госдумы болото...
# 23  Альбом ''Double Fantasy'' Джона Леннона и его ...
# 24  Кроме художественной прозы писал сатирические ...
# 25  Женщина с безупречной репутацией на посту прем...
# 26  До этого он успел поработать в известных IT-ко...
# 27  По словам Черноскулова, «от соперничества с Ан...
# 28  В те времена коммунистическое правительство Ку...
# 29  В ответ спикер Госдумы Сергей Нарышкин пообеща...
# 30  Ранее это сделал депутат от «Справедливой Росс...
# 31  Юноша клянется в преданности «халифу» аль-Багд...
# 32  Интересна дуэль вратарей: один из лучших канад...
# 33  Хотя у Мадуро нет харизмы Чавеса, он пользуетс...
# 34  «Согласно конституции, если инаугурация презид...
# 35  У Александра фантастическая защита, все надеял...
# 36  По сообщению портала Ivanovo News работы участ...
# 37  Речь идет о скандальном деле Mediaset, в рамка...
# 38  Насер стал вторым гражданином Индии, которому ...
# 39  Президент Бразилии Дилма Руссефф борется свою ...
# 40  В своём фейсбук-аккаунте Ивоби назвал главу «Л...
# 41  Напомним, что в 2011 году Бардо написала премь...
# 42  Netflix закрывает сериал «Карточный домик» на ...
# 43  Таким образом мошенникам удалось получить боле...
# 44  В случае описанной череды неудачных предложени...
# 45    Адвокаты лётчицы настаивают, что она невиновна.
# 46  Берлускони ушел в отставку немногим более года...
# 47  Скандально известная фигура в стране - Берлуск...
# 48  Столь же жесткой была партийная реакция на инт...
# 49  А вот у Bruins неожиданно блещут Давид Крейчи ...
#
#                         entity         pos  \
# 0                    Цвангираи  [206, 215]
# 1                     Mediaset    [29, 37]
# 2                 Давид Крейчи    [33, 45]
# 3                Дилме Руссефф    [20, 33]
# 4   технического правительства  [103, 129]
# 5                       Насера    [27, 33]
# 6                          США  [118, 121]
# 7                 писательницу    [34, 46]
# 8                 Джона Макафи    [59, 71]
# 9              Леонард Пелтиер    [30, 45]
# 10                      Google    [47, 53]
# 11               Кевина Спейси  [152, 165]
# 12               Крису Челиосу    [30, 43]
# 13                   политиков    [88, 97]
# 14               Грету Тунберг  [226, 239]
# 15               Джастин Бибер    [47, 60]
# 16              Дизайнеру ИГИЛ     [0, 14]
# 17                 Кирк Дуглас    [23, 34]
# 18                     Чеховым    [54, 61]
# 19                  футболиста    [28, 38]
# 20               Сумаила Сиссе    [49, 62]
# 21                     Алехина   [98, 105]
# 22                     Госдумы    [32, 39]
# 23               Марка Чепмена  [109, 122]
# 24                    юмористы  [154, 162]
# 25                     Нечасом   [93, 100]
# 26                         Sun    [65, 68]
# 27                     Андреем    [44, 51]
# 28                 The Beatles  [162, 173]
# 29                  Пономарева  [178, 188]
# 30               Единую Россию  [106, 119]
# 31                       Сирии  [144, 149]
# 32                   Тим Томас  [120, 129]
# 33                      Чавеса    [26, 32]
# 34                      Чавеса  [226, 232]
# 35                  Александра     [2, 12]
# 36                      ученые    [71, 77]
# 37                  Берлускони    [57, 67]
# 38                        ИГИЛ   [96, 100]
# 39               Дилма Руссефф    [19, 32]
# 40             Маттео Сальвини    [51, 66]
# 41                      Путину    [57, 63]
# 42              Кевином Спейси    [62, 76]
# 43                  Мардахаеву  [138, 148]
# 44                  президента    [48, 58]
# 45                     лётчицы     [9, 16]
# 46   правительство технократов  [128, 153]
# 47                  Берлускони    [39, 49]
# 48           федеральный центр  [125, 142]
# 49                Натан Хортон    [63, 75]
#
#                                         opinion_words  label
# 0                                     ['катастрофой']     -1
# 1                                     ['скандальном']     -1
# 2                                          ['блещут']      1
# 3                                       ['импичмент']     -1
# 4                                    ['не поддержит']     -1
# 5                               ['свидетелем против']     -1
# 6                                    ['недружелюбно']     -1
# 7                   ['интересных коротких рассказов']      1
# 8                                      ['параноиком']     -1
# 9         ['сомнений в справедливости его осуждения']      1
# 10                                        ['успехах']      1
# 11          ['глубокую озабоченность', 'обвинениями']     -1
# 12                                   ['легендарному']      1
# 13                              ['коппрумпированных']     -1
# 14                                      ['фаворитов']      1
# 15                                     ['Знаменитый']      1
# 16                                      ['обвинения']     -1
# 17                                       ['расцвета']      1
# 18  ['великим русским писателем', 'интересных коро...      1
# 19                                      ['именитого']      1
# 20                             ['фаворитом кампании']      1
# 21                                  ['отрицательную']     -1
# 22                                         ['болото']     -1
# 23                                        ['убийцей']     -1
# 24                                      ['известные']      1
# 25                                       ['скандала']     -1
# 26                                      ['известных']      1
# 27                                ['очень интересно']      1
# 28                            ['большим подозрением']     -1
# 29                          ['вруном', 'слово ранит']     -1
# 30                         ['партию жуликов и воров']     -1
# 31                                      ['неверными']     -1
# 32              ['один из лучших канадских вратарей']      1
# 33                                        ['харизмы']      1
# 34                                 ['поддерживающий']      1
# 35                                 ['фантастическая']      1
# 36                                       ['именитые']      1
# 37                                    ['скандальном']     -1
# 38                                      ['обвинения']     -1
# 39                                     ['импичменте']     -1
# 40                                ['великим лидером']      1
# 41                      ['президентом своего сердца']      1
# 42                                       ['скандала']     -1
# 43                                     ['мошенникам']     -1
# 44                                      ['неудачных']     -1
# 45                                      ['невиновна']     -1
# 46                                   ['непопулярную']     -1
# 47                                      ['обвинялся']     -1
# 48                    ['невнимание', 'раскритиковал']     -1
# 49                                         ['блещут']      1

# %%
submit = create_submit(predict)
submit
# Out:
#     sentiment                opinion_words
# 0          -1                   катастрофа
# 1          -1                  скандальном
# 2           1                       блещут
# 3          -1                       грозит
# 4          -1                 не поддержит
# 5          -1                       против
# 6          -1                       критик
# 7           1                нашим чеховым
# 8          -1                     параноик
# 9           1                     символом
# 10         -1         никак нельзя назвать
# 11         -1       глубокую озабоченность
# 12          1                  легендарный
# 13         -1                      заговор
# 14          1                     фавориты
# 15          1                   знаменитый
# 16         -1                    обвинения
# 17          1                      расцвет
# 18          1                нашим чеховым
# 19          1                     именитый
# 20          1                      фаворит
# 21         -1                    не желает
# 22         -1                       болото
# 23         -1                       убийца
# 24          1                    известные
# 25         -1                      скандал
# 26          1            наибольших заслуг
# 27          1                    интересно
# 28          1          большим подозрением
# 29         -1
# 30         -1
# 31         -1                     неверные
# 32          1                       лучший
# 33          1                популярностью
# 34          1               поддерживающий
# 35          1               фантастическая
# 36          1                     именитые
# 37         -1                    обвинялся
# 38         -1     намерении присоединиться
# 39         -1                    импечмент
# 40          1              великим лидером
# 41         -1
# 42         -1                      скандал
# 43         -1                    мошенники
# 44         -1                    неудачных
# 45          1                    невиновна
# 46         -1                 непопулярная
# 47         -1  скандально известная фигура
# 48         -1                      жесткой
# 49          1                       блещут

# %%
len(df), len(submit)
# Out:
# (50, 50)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(df['label'], submit['sentiment'])
# Out:
# 0.92

# %%
def eval_submit(submit, df):
    lcs_score = []
    edit_score = []
    for i in range(len(submit)):
        answers = eval(df.iloc[i]['opinion_words'])
        response = submit.iloc[i]['opinion_words']
        eval_res = eval_words(response, answers)
        lcs_score.append(eval_res[1])
        edit_score.append(eval_res[2])
    return accuracy_score(df['label'], submit['sentiment']), np.mean(lcs_score), np.mean(edit_score)

# %%
eval_submit(submit, df)
# Out:
# (0.92, 0.577101848373248, 0.5609813097308293)

# %%
for

# %%
lcs_score = []
edit_score = []
for i in range(len(submit)):
    answers = eval(df.iloc[i]['opinion_words'])
    response = submit.iloc[i]['opinion_words']
    eval_res = eval_words(response, answers)
    lcs_score.append(eval_res[1])
    edit_score.append(eval_res[2])
np.mean(lcs_score), np.mean(edit_score)
# Out:
# (0.577101848373248, 0.5609813097308293)

# %%
edit_score
# Out:
# [0.5,
#  1.0,
#  1.0,
#  0.3010299956639812,
#  1.0,
#  0.27023815442731974,
#  0.27023815442731974,
#  0.20801459767650948,
#  0.5,
#  0.19342640361727081,
#  0.23137821315975915,
#  1.0,
#  0.43067655807339306,
#  0.24465054211822604,
#  0.5,
#  1.0,
#  1.0,
#  0.6309297535714575,
#  0.22106472945750374,
#  0.43067655807339306,
#  0.27023815442731974,
#  0.27023815442731974,
#  1.0,
#  0.5,
#  1.0,
#  0.6309297535714575,
#  0.23981246656813146,
#  0.3333333333333333,
#  1.0,
#  0.3333333333333333,
#  0.21810429198553155,
#  0.5,
#  0.20584683246043448,
#  0.26264953503719357,
#  1.0,
#  1.0,
#  1.0,
#  0.27894294565112987,
#  0.227670248696953,
#  0.5,
#  1.0,
#  0.2103099178571525,
#  0.6309297535714575,
#  0.5,
#  1.0,
#  1.0,
#  0.5,
#  0.21533827903669653,
#  0.2890648263178879,
#  1.0]

# %%
lcs_score
# Out:
# [0.8181818181818182,
#  1.0,
#  1.0,
#  0.1111111111111111,
#  1.0,
#  0.35294117647058826,
#  0.08333333333333333,
#  0.06896551724137931,
#  0.8,
#  0.05128205128205128,
#  0.05,
#  1.0,
#  0.75,
#  0.11764705882352941,
#  0.7777777777777778,
#  1.0,
#  1.0,
#  0.875,
#  0.12,
#  0.6666666666666666,
#  0.3888888888888889,
#  0.15384615384615385,
#  1.0,
#  0.7142857142857143,
#  1.0,
#  0.875,
#  0.058823529411764705,
#  0.6,
#  1.0,
#  0.0,
#  0.0,
#  0.7777777777777778,
#  0.15151515151515152,
#  0.07692307692307693,
#  1.0,
#  1.0,
#  1.0,
#  0.09090909090909091,
#  0.125,
#  0.5,
#  1.0,
#  0.0,
#  0.875,
#  0.8,
#  1.0,
#  1.0,
#  0.8333333333333334,
#  0.037037037037037035,
#  0.15384615384615385,
#  1.0]

# %%
eval_res
# Out:
# [0.6590909090909092, 0.8181818181818182, 0.5, 'катастрофой']

# %%
predict_sentiment_res = []
for i, pred in enumerate(predict):
    sentiment = -1
    try:
        pred = eval(pred)
        sentiment = pred['тональность'].strip().lower()
        words = pred['ценочное слово'].strip().lower()

        sentiment = -1 if sentiment == 'негативная' else 1
        predict_sentiment_res
    except:
        pass

# %%
predict
# Out:
# ['{\n  "тональность": "негативная",\n  "оценочное слово": "катастрофа"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "скандальном"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "блещут"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "грозит"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "не поддержит"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "против"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "критик"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "нашим Чеховым"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "параноик"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "символом"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "никак нельзя назвать"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "глубокую озабоченность"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "легендарный"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "заговор"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "фавориты"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "знаменитый"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "обвинения"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "расцвет"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "нашим Чеховым"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "именитый"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "фаворит"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "не желает"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "болото"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "убийца"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "известные"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "скандал"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "наибольших заслуг"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "интересно"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "большим подозрением"\n}',
#  'тональность: негативная\nоценочное слово: врун',
#  'тональность: негативная\nоценочное слово: партия жуликов и воров',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "неверные"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "лучший"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "популярностью"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "поддерживающий"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "фантастическая"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "именитые"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "обвинялся"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "намерении присоединиться"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "импечмент"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "великим лидером"\n}',
#  'тональность: положительная\nоценочное слово: благодарность',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "скандал"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "мошенники"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "неудачных"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "невиновна"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "непопулярная"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "скандально известная фигура"\n}',
#  '{\n  "тональность": "негативная",\n  "оценочное слово": "жесткой"\n}',
#  '{\n  "тональность": "положительная",\n  "оценочное слово": "блещут"\n}']

# %%
answers.append('катастрофический')

# %%
answers.append('катастрофа')

# %%
eval(response, answers)
# Out:
# [[1.0, 1.0, 1.0, 'катастрофа'],
#  [0.6590909090909092, 0.8181818181818182, 0.5, 'катастрофой'],
#  [0.4389824383928644, 0.5625, 0.31546487678572877, 'катастрофический'],
#  [0.4389824383928644, 0.5625, 0.31546487678572877, 'катастрофический']]

# %%
find_lcs(response.strip().lower(), answers[-1].strip().lower())
# Out:
# 'катастроф'

# %%
response
# Out:
# 'катастрофа'

# %%
final_response = clean_func(response, record["entities"])
record["prediction"] = final_response
answers = record["answers"]
if answers:
    all_count += 1
    prediction = record["prediction"].strip().lower()
    for answer in answers:
        answer = answer.strip().lower()
        if edit_distance(answer, prediction) <= 2:
            correct_count += 1
            break

# %%
len(LCS_HIRSHBERG('катастрофа', 'катастрофой'))
# Out:
# 9

# %%
def check

# %%
print(prompt)
# Out:
# <s>system
# Ты — Сайга, русскоязычный автоматический ассистент. Ты разговариваешь с людьми и помогаешь им.</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: Речь идет о скандальном деле Mediaset, в рамках которого Берлускони обвинялся в масштабных финансовых махинациях.
# Сущность: Mediaset</s><s>bot

# %%
r.text
# Out:
# '{"status":"ok","text":"обвинениями\\"\\n}"}'

# %%
print(prompt)
# Out:
# <s>system
# Ты — Сайга, русскоязычный автоматический ассистент. Ты разговариваешь с людьми и помогаешь им.</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: В этой публикации утверждается, что президент стала жертвой «заговора коппрумпированных политиков», направленного против Бразилии, демократии и, в первую очередь, против граждан страны.
# Сущность: политиков</s><s>bot
# {
#   "тональность": "негативная",
#   "оценочное слово": "коппрумпированных"
# }</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: При этом ''Netflix'' выразил глубокую озабоченность в связи с появившимися сутки назад обвинениями в адрес сыгравшего главную роль в «Карточном домике» Кевина Спейси.
# Сущность: Кевина Спейси</s><s>bot
# {
#   "тональность": "негативная",
#   "оценочное слово": "глубокую озабоченность;обвинениями"
# }</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: А вот у Bruins неожиданно блещут Давид Крейчи (десять голов) и Натан Хортон (восемь шайб).
# Сущность: Натан Хортон</s><s>bot
# {
#   "тональность": "положительная",
#   "оценочное слово": "блещут"
# }</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: В пресс-релизе говорится, что Леонард Пелтиер стал для всего мира символом несправедливости американской судебной системы в силу наличия множества сомнений в справедливости его осуждения в 1977 году.
# Сущность: Леонард Пелтиер</s><s>bot
# {
#   "тональность": "положительная",
#   "оценочное слово": "сомнений в справедливости его осуждения"
# }</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: В своём фейсбук-аккаунте Ивоби назвал главу «Лиги» Маттео Сальвини «великим лидером», который привёл партию к победе.
# Сущность: Маттео Сальвини</s><s>bot
# {
#   "тональность": "положительная",
#   "оценочное слово": "великим лидером"
# }</s><s>user
# Определи какая тональность по отношению к сущности в предложении, врианты ответа: положительная, негативная. Помимо тональности точно извлеки из предложения одно или несколько слов, которые выражают данную тональность. Результат приведи в формате json с полями "тональность" и "оценочное слово".
# Предложение: А вот у Bruins неожиданно блещут Давид Крейчи (десять голов) и Натан Хортон (восемь шайб).
# Сущность: Давид Крейчи</s><s>bot

# %%
json.loads(r.text)['text']
# Out:
# '{\n  "тональность": "положительная",\n  "оценочное слово": "блещут"\n}'

# %%
inputs = ["?"]
for inp in inputs:
    conversation = Conversation()
    conversation.add_user_message(inp)
    prompt = conversation.get_prompt()

# %%
import json
host = 'http://localhost:5005/generate'
r = requests.post(host, json.dumps({'model_name': 'mistral_ru', 'prompt': prompt}))

# %%
r.text
# Out:
# '{"status":"ok","text":"Зеленый цвет у растений обусловлен наличием в них хлорофилла - пигмента, который позволяет растениям совершать фотосинтез. Фотосинтез - это процесс, благодаря которому растения превращают свет в энергию, используя его для роста и развития. Хлорофилл поглощает световые волны длиной 430-450 нм (синий цвет) и 670-680 нм (красный цвет), что создает ощущение зеленого цвета."}'
